# %%
#Importando as bilbiotecas necessárias
import pandas as pd

# %%
#lendo o dataset (pode demorar um pouco devido a seu tamanho)
dados = pd.read_table('MICRODADOS_ENEM_2019.csv', delimiter=';',encoding='ISO-8859-1')

# %%
#limpando os dados
#foram removidos todos que faltaram em algum dia da prova e que tiveram a redação em branco
dados = dados.loc[dados['TP_PRESENCA_LC']==1]

# %%
dados = dados.loc[dados['TP_PRESENCA_MT']==1]

# %%
dados = dados.loc[dados['TP_PRESENCA_CN']==1]

# %%
dados = dados.loc[dados['TP_PRESENCA_CH']==1]

# %%
dados = dados.loc[dados['TP_STATUS_REDACAO']==1]

# %%
#Seleção de colunas com informações que serão utilizadas
colunas = ['NO_MUNICIPIO_RESIDENCIA', 'SG_UF_RESIDENCIA', 'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE', 'NO_MUNICIPIO_NASCIMENTO','SG_UF_NASCIMENTO', 'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO', 'IN_TREINEIRO']
dados_limpos = dados[colunas]

# %%
dados_limpos
# Out:
#         NO_MUNICIPIO_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  \
# 0                      Santarém               PA        21       M
# 1                    Mãe do Rio               PA        16       F
# 2                   Paragominas               PA        18       F
# 5                    Ananindeua               PA        31       M
# 6                        Marabá               PA        30       F
# ...                         ...              ...       ...     ...
# 5095261                Salvador               BA        27       F
# 5095262             Santo Amaro               BA        22       F
# 5095263               Cansanção               BA        32       M
# 5095268                Salvador               BA        16       M
# 5095269                 Itabuna               BA        25       F
#
#          TP_ESTADO_CIVIL  TP_COR_RACA  TP_NACIONALIDADE  \
# 0                      1            3                 4
# ...
